# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Colab/ECE684
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab/ECE684

# %%
def build_descriptive_text_vocab(input_text):
  vocab = set()
  vocab.add("<UNK>")
  for text in input_text:
    for word in text.split():
      word = remove_punctuation(word)
      if word:
        vocab.add(word)
  return {token: i for i, token in enumerate(vocab)}

def vectorize_descriptive_text(input_text, vocab):
  vectorized_text = np.zeros(len(vocab))
  for word in input_text.split():
    word = remove_punctuation(word)
    if word in vocab:
      vectorized_text[vocab[word]] += 1
    else:
      vectorized_text[vocab["<UNK>"]] += 1
  return vectorized_text

def remove_punctuation(word):
    punctuation = set([".", "(", ")", ",", ";", "?", "!", '"', ":", "'"])
    while word and word[0] in punctuation:
        word = word[1:]
    while word and word[-1] in punctuation:
        word = word[:-1]
    return word.lower()

# %%
train_data = pd.read_csv('train.csv')
V = build_descriptive_text_vocab(train_data['statement'])

test_statement = "chores chores stunt chores stunt chores ontario the"
test_vector = vectorize_descriptive_text(test_statement, V)
print(test_vector)
# Out:
# {'chores': 0, 'stunt': 1, 'ontario': 2, 'rebecca': 3, 'rigell': 4, '96': 5, 'undergoing': 6, 'kid-friendly': 7, 'military-funded': 8, 'associations': 9, 'gearing': 10, 'saints': 11, 'futures': 12, 'comedy': 13, 'dipping': 14, 'explorer': 15, 'complication': 16, 'landing': 17, 'river': 18, 'handcuff': 19, 'bounties': 20, '3.6': 21, '62': 22, '1960s': 23, "kaine's": 24, 'desantis': 25, 'kanye': 26, 'anyway': 27, 'labs': 28, "dean's": 29, 'protective': 30, 'notoriously': 31, 'boring': 32, "romney's": 33, 'circumvents': 34, 'swimming': 35, 'donned': 36, 'adler': 37, 'encouraging': 38, 'clapping': 39, 'knocks': 40, 'disfavored': 41, '$1,650': 42, 'ineligible': 43, 'wisconsin': 44, 'derby': 45, 'hoping': 46, 'safeguard': 47, 'flowering': 48, 'richness': 49, 'stops': 50, 'haze': 51, 'segregated': 52, 'snl': 53, 'abusing': 54, '30-year-olds': 55, 'lolling': 56, 'shortages': 57, 'blacks': 58, 'packs': 59, 'talked': 60, 'trust': 61, "booker's": 62, 'protests': 63, 'advised': 64, 'nash': 65, 'paratroopers': 66, 'jail-time': 67, 'cocktails': 68, '142': 69, 'overgrown': 70, 'sheila': 71, 'slaps': 72, 'criminalize': 73, "tonight's": 74, 'male': 75, 'employer-provided': 76, 'census': 77, 'cadillac': 78, 'verifying': 79, 'udall': 80, 'fhp': 81, 'appropriately': 82, '#usmca': 83, 'eligibility': 84, 'reversing': 85, 'year-olds': 86, '2006': 87, 'yogurt': 88, 'averaged': 89, 'crosses': 90, 'large': 91, 'r-wisconsin': 92, 'once-in-a-century': 93, 'warmer': 94, "deal's": 95, 'started': 96, 'co-worker': 97, 'strictly': 98, 'corn': 99, 'rigs': 100, 'homosexuality': 101, "atwater's": 102, "killer's": 103, 'clandestine': 104, 'fyi': 105, 'warmed': 106, 'miracle': 107, 'deformed': 108, 'destination': 109, 'sentence': 110, 'voicing': 111, 'st': 112, 'defect': 113, 'wednesday': 114, 'violating': 115, 'ours': 116, 'invests': 117, 'detail': 118, 'grammys': 119, 'detaining': 120, 'password': 121, 'catfish': 122, 'sunday': 123, 'lend': 124, 'schwarzenegger': 125, 'marvin': 126, 'parole': 127, 'merrick': 128, 'murder': 129, 'set': 130, 'dell': 131, 'forecasts': 132, 'pension': 133, 'generator': 134, 'drill': 135, 'ford': 136, 'marxists': 137, 'democracy': 138, 'afghanistan….forgets': 139, 'lifeguard/football': 140, 'gym': 141, 'coded': 142, 'multi-millionaire': 143, 's': 144, 'succeeds': 145, 'racists': 146, 'upscale': 147, 'regular': 148, 'pembroke': 149, 'porous': 150, 'inoculated': 151, 'disenfranchises': 152, 'habitability': 153, 'fifty-four': 154, 'independent-minded': 155, 'holidaying': 156, 'adelson': 157, 'drillers': 158, 'split': 159, 'ḍozen': 160, 'ballistic': 161, 'recognized': 162, 'retreated': 163, 'emergency': 164, 'jill': 165, '207,000': 166, 'worse': 167, 'legalized': 168, "jehovah's": 169, 'tip': 170, 'flowed': 171, 'kente': 172, 'fear': 173, 'youth': 174, 'negotiates': 175, 'confesses': 176, 'sheep': 177, 'ancient': 178, 'dwight': 179, 'glitch': 180, 'pin': 181, 'three-cents-per-ounce': 182, 'syria': 183, 'eckhardt': 184, '2,809': 185, 'awaiting': 186, 'belly': 187, 'air-quality': 188, '11,000,000': 189, 'cleaned': 190, 'self-defense': 191, 'nuclear-armed': 192, '$3.3': 193, 'tax-cut': 194, 'meet': 195, 'carve-out': 196, 'backyard': 197, 'tribal': 198, '$805': 199, '1,900': 200, 'jade': 201, 'finishing': 202, 'evian': 203, 'eo': 204, 'couple': 205, 'lifestyles': 206, 'promotion': 207, 'partners': 208, 'real-life': 209, 'regardless': 210, 'russ': 211, 'aspersions': 212, 'louisiana': 213, 'malcolm': 214, 'clerk': 215, 'terminating': 216, 'kid': 217, 'degraded': 218, 'lpciminelli': 219, 'reinstated': 220, 'imaging': 221, 'burdens': 222, '74,000': 223, 'jinping': 224, 'flocks': 225, 'matter': 226, 'ethylene': 227, 'shift': 228, 'disease': 229, "usa's": 230, '[e]mployment': 231, 'heroes': 232, 'financiers': 233, 'realizes': 234, 'cullman': 235, 'unfulfilled': 236, 'steyer': 237, 'top-to-bottom': 238, 'deem': 239, 'pocket': 240, 'deceptively': 241, 'lab': 242, 'issued': 243, 'disrupt': 244, 'repaired': 245, 'non-racist': 246, 'sixth-richest': 247, ...
# 8.0
